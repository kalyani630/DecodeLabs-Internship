# %%
import  pandas as pd

# %%
#Dataset
df = pd.read_excel("Dataset for Data Analytics.xlsx")
df
# Out:
#         OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 0     ORD200000 2023-01-04     C72649  Monitor         5     570.62
# 1     ORD200001 2024-08-23     C75739    Phone         2     151.35
# 2     ORD200002 2024-02-27     C81728   Tablet         5     550.68
# 3     ORD200003 2023-10-15     C33540    Chair         1     273.19
# 4     ORD200004 2025-05-08     C81840  Printer         4     626.01
# ...         ...        ...        ...      ...       ...        ...
# 1195  ORD201195 2024-06-20     C21126     Desk         1     107.04
# 1196  ORD201196 2024-03-04     C20095  Monitor         2     662.53
# 1197  ORD201197 2023-07-13     C79674   Tablet         2     436.84
# 1198  ORD201198 2024-08-22     C64753    Chair         4     262.52
# 1199  ORD201199 2023-06-11     C57502   Tablet         4     560.58
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# ...

# %%
#Shape of dataset
print("Shape of dataset:",df.shape)
#Dataset information
df.info()
# Out:
# Shape of dataset: (1200, 14)
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          1200 non-null   str
#  1   Date             1200 non-null   datetime64[us]
#  2   CustomerID       1200 non-null   str
#  3   Product          1200 non-null   str
#  4   Quantity         1200 non-null   int64
#  5   UnitPrice        1200 non-null   float64
#  6   ShippingAddress  1200 non-null   str
#  7   PaymentMethod    1200 non-null   str
#  8   OrderStatus      1200 non-null   str
#  9   TrackingNumber   1200 non-null   str
#  10  ItemsInCart      1200 non-null   int64
#  11  CouponCode       891 non-null    str
#  12  ReferralSource   1200 non-null   str
#  13  TotalPrice       1200 non-null   float64
# dtypes: datetime64[us](1), float64(2), int64(2), str(9)
# memory usage: 131.4 KB

# %%
#Identifying Null Values
print("Missing / Null Values in each column:")
df.isnull().sum()
# Out:
# Missing / Null Values in each column:
# OrderID              0
# Date                 0
# CustomerID           0
# Product              0
# Quantity             0
# UnitPrice            0
# ShippingAddress      0
# PaymentMethod        0
# OrderStatus          0
# TrackingNumber       0
# ItemsInCart          0
# CouponCode         309
# ReferralSource       0
# TotalPrice           0
# dtype: int64

# %%
#CouponCode has null values
print("Records with null values in CouponCode column:S")
df[df["CouponCode"].isnull()]
# Out:
# Records with null values in CouponCode column:S
#         OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 8     ORD200008 2025-04-02     C26817    Phone         2     134.28
# 15    ORD200015 2023-07-17     C39416  Printer         1     473.96
# 17    ORD200017 2024-03-02     C60672   Tablet         1     423.40
# 21    ORD200021 2024-11-17     C99023  Monitor         4     342.95
# 26    ORD200026 2024-03-06     C21944   Laptop         5      59.55
# ...         ...        ...        ...      ...       ...        ...
# 1172  ORD201172 2025-02-04     C28828     Desk         3     131.96
# 1184  ORD201184 2023-09-27     C10222   Laptop         1     204.08
# 1189  ORD201189 2024-08-17     C96136   Tablet         5     389.22
# 1192  ORD201192 2024-02-28     C72007    Chair         3     432.85
# 1196  ORD201196 2024-03-04     C20095  Monitor         2     662.53
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# ...

# %%
#Identifying Duplicate rows
print("\nNumber of Duplicate Rows:", df.duplicated().sum())
# Out:
# Number of Duplicate Rows: 0

# %%
#No duplicate records exist

# %%
print("\nCurrent Data Types:")
df.dtypes
# Out:
# Current Data Types:
# OrderID                       str
# Date               datetime64[us]
# CustomerID                    str
# Product                       str
# Quantity                    int64
# UnitPrice                 float64
# ShippingAddress               str
# PaymentMethod                 str
# OrderStatus                   str
# TrackingNumber                str
# ItemsInCart                 int64
# CouponCode                    str
# ReferralSource                str
# TotalPrice                float64
# dtype: object

# %%
#All columns are already in the correct data formats. No conversion is needed

# %%
#Handling Missing Values
df['CouponCode']=df['CouponCode'].fillna('No Coupon Code')
df.isnull().sum()
# Out:
# OrderID            0
# Date               0
# CustomerID         0
# Product            0
# Quantity           0
# UnitPrice          0
# ShippingAddress    0
# PaymentMethod      0
# OrderStatus        0
# TrackingNumber     0
# ItemsInCart        0
# CouponCode         0
# ReferralSource     0
# TotalPrice         0
# dtype: int64

# %%
#Cleaned Excel
df.to_excel("Cleaned Dataset for Data Analytics.xlsx",index=False)
print("DataSet exported to Excel successfully.")
# Out:
# DataSet exported to Excel successfully.
